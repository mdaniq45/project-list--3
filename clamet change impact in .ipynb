# %% [markdown]
# ### import laberary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import  seaborn as sns
import warnings

# %%
df=pd.read_csv('climate_change_impact_on_agriculture_2024.csv')

# %%
df
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
df.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
df.describe()
# Out:
#                Year  Average_Temperature_C  Total_Precipitation_mm  \
# count  10000.000000           10000.000000            10000.000000
# mean    2007.088700              15.241299             1611.663834
# std       10.084245              11.466955              805.016815
# min     1990.000000              -4.990000              200.150000
# 25%     1999.000000               5.430000              925.697500
# 50%     2007.000000              15.175000             1611.160000
# 75%     2016.000000              25.340000             2306.997500
# max     2024.000000              35.000000             2999.670000
#
#        CO2_Emissions_MT  Crop_Yield_MT_per_HA  Extreme_Weather_Events  \
# count      10000.000000          10000.000000            10000.000000
# mean          15.246608              2.240017                4.980900
# std            8.589423              0.998342                3.165808
# min            0.500000              0.450000                0.000000
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         10000 non-null  int64
#  1   Country                      10000 non-null  object
#  2   Region                       10000 non-null  object
#  3   Crop_Type                    10000 non-null  object
#  4   Average_Temperature_C        10000 non-null  float64
#  5   Total_Precipitation_mm       10000 non-null  float64
#  6   CO2_Emissions_MT             10000 non-null  float64
#  7   Crop_Yield_MT_per_HA         10000 non-null  float64
#  8   Extreme_Weather_Events       10000 non-null  int64
#  9   Irrigation_Access_%          10000 non-null  float64
#  10  Pesticide_Use_KG_per_HA      10000 non-null  float64
#  11  Fertilizer_Use_KG_per_HA     10000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Year                           0
# Country                        0
# Region                         0
# Crop_Type                      0
# Average_Temperature_C          0
# Total_Precipitation_mm         0
# CO2_Emissions_MT               0
# Crop_Yield_MT_per_HA           0
# Extreme_Weather_Events         0
# Irrigation_Access_%            0
# Pesticide_Use_KG_per_HA        0
# Fertilizer_Use_KG_per_HA       0
# Soil_Health_Index              0
# Adaptation_Strategies          0
# Economic_Impact_Million_USD    0
# dtype: int64

# %%
df.dropna()
# Out:
#       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
df.fillna
# Out:
# <bound method NDFrame.fillna of       Year    Country              Region  Crop_Type  Average_Temperature_C  \
# 0     2001      India         West Bengal       Corn                   1.55
# 1     2024      China               North       Corn                   3.23
# 2     2001     France       Ile-de-France      Wheat                  21.11
# 3     2001     Canada            Prairies     Coffee                  27.85
# 4     1998      India          Tamil Nadu  Sugarcane                   2.19
# ...    ...        ...                 ...        ...                    ...
# 9995  2022     France  Nouvelle-Aquitaine     Cotton                  30.48
# 9996  1999  Australia          Queensland   Soybeans                   9.53
# 9997  2000  Argentina           Patagonia     Coffee                  31.92
# 9998  1996     Brazil           Southeast   Soybeans                  13.95
# 9999  2015      China               South       Corn                  11.78
#
# ...

# %%
df_cleaned=df.dropna()

# %%
df_filled=df.fillna(0)

# %%
df.head(1)
# Out:
#    Year Country       Region Crop_Type  Average_Temperature_C  \
# 0  2001   India  West Bengal      Corn                   1.55
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                     14.78              83.25      Water Management
#
#    Economic_Impact_Million_USD
# 0                       808.13

# %%
plt.figure(figsize=(12,8))
sns.barplot(x='Region', y='Average_Temperature_C', data=df, estimator='mean')
plt.title('Average_Temperature')
plt.xlabel('resion')
plt.ylabel('Average Temperature')
plt.xticks('rotation=45')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.lineplot(x='Year', y='Crop_Yield_MT_per_HA', data=df)
# Out:
# <Axes: xlabel='Year', ylabel='Crop_Yield_MT_per_HA'>

# %%
plt.figure(figsize=(12,10))
df['Crop_Type'].value_counts().plot.pie(autopct='%1.1f%%', startangle=140)

plt.title("persentage of   country of drops types")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.histplot(df['CO2_Emissions_MT'], bins=30,kde=True)
# Out:
# <Axes: xlabel='CO2_Emissions_MT', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x="Country", y='Crop_Yield_MT_per_HA', data=df)
# Out:
# <Axes: xlabel='Country', ylabel='Crop_Yield_MT_per_HA'>

# %%
df.head(1)
# Out:
#    Year Country       Region Crop_Type  Average_Temperature_C  \
# 0  2001   India  West Bengal      Corn                   1.55
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index Adaptation_Strategies  \
# 0                     14.78              83.25      Water Management
#
#    Economic_Impact_Million_USD
# 0                       808.13

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='CO2_Emissions_MT',y='Crop_Yield_MT_per_HA',data=df)
# Out:
# <Axes: xlabel='CO2_Emissions_MT', ylabel='Crop_Yield_MT_per_HA'>

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
sns.pairplot(df([[  'Average_Temperature_C',
       'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
       'Extreme_Weather_Events', 'Irrigation_Access_%',
       'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
       'Soil_Health_Index', 'Adaptation_Strategies']]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 sns.pairplot(df([[  'Average_Temperature_C',
#       2        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#       3        'Extreme_Weather_Events', 'Irrigation_Access_%',
#       4        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#       5        'Soil_Health_Index', 'Adaptation_Strategies']]))
#
# TypeError: 'DataFrame' object is not callable

# %%
df.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %%
plt.figure(figsize=(12,10))
sns.boxplot(x='Region',y='Economic_Impact_Million_USD', data=df)
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.violinplot(x='Crop_Type',y='Irrigation_Access_%',data=df)
plt.title('Irrigation_Access %')
# Out:
# Text(0.5, 1.0, 'Irrigation_Access %')

# %%
plt.figure(figsize=(12,10))
sns.countplot(x='Region',hue='Extreme_Weather_Events',data=df)
plt.title('Extreme_Weather_Events by resion')
plt.xlabel('resion')
plt.ylabel('count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.lineplot(x='Year',y='Pesticide_Use_KG_per_HA', data=df)
plt.title("Pesticide use over the year")
# Out:
# Text(0.5, 1.0, 'Pesticide use over the year')

# %%
plt.figure(figsize=(12,10))
sns.histplot(df['Soil_Health_Index'], bins=30,kde=True)
plt.title('Soil_Health_ index')
# Out:
# Text(0.5, 1.0, 'Soil_Health_ index')

# %%
sns.pairplot(df[['Crop_Yield_MT_per_HA', 'Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT']])
plt.title('Pairwise Relationships of Crop Yield and Environmental Factors')
plt.show()
