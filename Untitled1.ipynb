# %%
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Customer Purchasing Behaviors.csv")

# %% [markdown]
# df

# %% [markdown]
# ### data exploration

# %%
df.head()
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
# 1        2   34          55000              350            7.0  South
# 2        3   45          65000              500            8.0   West
# 3        4   22          30000              150            3.0   East
# 4        5   29          47000              220            4.8  North
#
#    purchase_frequency
# 0                  12
# 1                  18
# 2                  22
# 3                  10
# 4                  13

# %%
df.tail()
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 233      234   40          60000              450            7.2   West
# 234      235   38          59000              430            6.9  North
# 235      236   54          74000              630            9.4  South
# 236      237   32          52000              360            5.8   West
# 237      238   31          51000              340            5.6  North
#
#      purchase_frequency
# 233                  20
# 234                  20
# 235                  27
# 236                  18
# 237                  17

# %%
df.sample(n=4)
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 222      223   46          66000              510            8.1  North
# 189      190   30          49000              300            5.0  North
# 194      195   52          72000              610            9.2   West
# 61        62   33          53000              380            6.0  South
#
#      purchase_frequency
# 222                  22
# 189                  16
# 194                  26
# 61                   18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             238 non-null    int64
#  1   age                 238 non-null    int64
#  2   annual_income       238 non-null    int64
#  3   purchase_amount     238 non-null    int64
#  4   loyalty_score       238 non-null    float64
#  5   region              238 non-null    object
#  6   purchase_frequency  238 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 13.1+ KB

# %%
df.describe()
# Out:
#           user_id         age  annual_income  purchase_amount  loyalty_score  \
# count  238.000000  238.000000     238.000000       238.000000     238.000000
# mean   119.500000   38.676471   57407.563025       425.630252       6.794118
# std     68.848868    9.351118   11403.875717       140.052062       1.899047
# min      1.000000   22.000000   30000.000000       150.000000       3.000000
# 25%     60.250000   31.000000   50000.000000       320.000000       5.500000
# 50%    119.500000   39.000000   59000.000000       440.000000       7.000000
# 75%    178.750000   46.750000   66750.000000       527.500000       8.275000
# max    238.000000   55.000000   75000.000000       640.000000       9.500000
#
#        purchase_frequency
# count          238.000000
# mean            19.798319
# std              4.562884
# min             10.000000
# 25%             17.000000
# 50%             20.000000
# 75%             23.000000
# max             28.000000

# %%
df.isnull()
# Out:
#      user_id    age  annual_income  purchase_amount  loyalty_score  region  \
# 0      False  False          False            False          False   False
# 1      False  False          False            False          False   False
# 2      False  False          False            False          False   False
# 3      False  False          False            False          False   False
# 4      False  False          False            False          False   False
# 5      False  False          False            False          False   False
# 6      False  False          False            False          False   False
# 7      False  False          False            False          False   False
# 8      False  False          False            False          False   False
# 9      False  False          False            False          False   False
# 10     False  False          False            False          False   False
# ...

# %%
df.isnull().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
#df['column'].unique()

# %%
#df['column'].unique()

# %%
#df['columns'].value_counts()

# %%
print(df.columns)
# Out:
# Index(['user_id', 'age', 'annual_income', 'purchase_amount', 'loyalty_score',
#        'region', 'purchase_frequency'],
#       dtype='object')

# %%
df['age'].value_counts()
# Out:
# age
# 33    14
# 24    14
# 41    14
# 50    14
# 29     9
# 31     9
# 37     8
# 52     8
# 26     8
# 46     8
# 40     8
# 39     8
# 49     8
# 30     8
# 38     8
# 28     8
# 27     8
# 36     8
# 45     8
# 32     8
# 43     7
# 55     7
# 48     7
# 51     7
# 54     7
# 42     7
# 34     2
# 25     2
# 47     1
# 35     1
# 44     1
# 23     1
# 22     1
# 53     1
# Name: count, dtype: int64

# %%
df[['user_id', 'age', 'annual_income', 'purchase_amount', 'loyalty_score',
       'region', 'purchase_frequency']]
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df.memory_usage(deep=True)
# Out:
# Index                   132
# user_id                1904
# age                    1904
# annual_income          1904
# purchase_amount        1904
# loyalty_score          1904
# region                14673
# purchase_frequency     1904
# dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
pd.set_option('display.max_columns', None)

# %%
df.cov
# Out:
# <bound method DataFrame.cov of      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=238, step=1)

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             238 non-null    int64
#  1   age                 238 non-null    int64
#  2   annual_income       238 non-null    int64
#  3   purchase_amount     238 non-null    int64
#  4   loyalty_score       238 non-null    float64
#  5   region              238 non-null    object
#  6   purchase_frequency  238 non-null    int64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 13.1+ KB

# %% [markdown]
# ### data cleaning

# %%
df.dropna()
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
#df.fillna(value)

# %%
#df.fillna(df.mean())

# %%
df.isnull().sum()
# Out:
# user_id               0
# age                   0
# annual_income         0
# purchase_amount       0
# loyalty_score         0
# region                0
# purchase_frequency    0
# dtype: int64

# %%
df.fillna(method='ffill')
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_17904\1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# ...

# %%
df.fillna(method='bfill')
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_17904\2831856154.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill')
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# ...

# %%
df.replace({'purchase_frequency':'purchas'})
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df.head(1)
# Out:
#    user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0        1   25          45000              200            4.5  North
#
#    purchase_frequency
# 0                  12

# %%
df.replace({'user_id':'id', 'annual_income':'yeaely income'})
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df.drop_duplicates()
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df[(df['purchase_amount']>600)]
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 20        21   52          72000              610            9.2  South
# 34        35   55          75000              640            9.5  South
# 38        39   53          73000              620            9.3   West
# 44        45   52          72000              610            9.2   West
# 55        56   54          74000              630            9.4  South
# 59        60   55          75000              640            9.5   West
# 74        75   52          72000              610            9.2   West
# 85        86   54          74000              630            9.4  South
# 89        90   55          75000              640            9.5   West
# 104      105   52          72000              610            9.2   West
# 115      116   54          74000              630            9.4  South
# 119      120   55          75000              640            9.5   West
# ...

# %%
#df=df.drop(['loyalty_score','region'] ,axis=1)

# %%
df
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 0          1   25          45000              200            4.5  North
# 1          2   34          55000              350            7.0  South
# 2          3   45          65000              500            8.0   West
# 3          4   22          30000              150            3.0   East
# 4          5   29          47000              220            4.8  North
# 5          6   41          61000              480            7.8  South
# 6          7   36          54000              400            6.5   West
# 7          8   27          43000              230            4.2   East
# 8          9   50          70000              600            9.0  North
# 9         10   31          50000              320            5.5  South
# 10        11   28          46000              250            4.4   West
# 11        12   42          62000              520            8.2  North
# ...

# %% [markdown]
# # data manipulation

# %%
df['age']
# Out:
# 0      25
# 1      34
# 2      45
# 3      22
# 4      29
# 5      41
# 6      36
# 7      27
# 8      50
# 9      31
# 10     28
# 11     42
# 12     33
# 13     37
# 14     49
# 15     23
# 16     39
# 17     30
# 18     46
# 19     26
# 20     52
# 21     24
# 22     44
# 23     35
# 24     38
# 25     47
# 26     32
# 27     29
# 28     51
# 29     40
# 30     34
# 31     43
# 32     31
# 33     27
# 34     55
# 35     25
# 36     48
# 37     30
# 38     53
# 39     28
# 40     39
# 41     37
# 42     46
# 43     33
# 44     52
# 45     29
# 46     41
# 47     50
# 48     36
# 49     24
# 50     49
# 51     26
# 52     45
# 53     40
# 54     38
# 55     54
# 56     32
# 57     31
# 58     42
# 59     55
# 60     29
# 61     33
# 62     51
# 63     27
# 64     43
# 65     41
# 66     50
# 67     24
# 68     48
# 69     30
# 70     39
# 71     37
# 72     46
# 73     33
# 74     52
# 75     28
# 76     41
# 77     50
# 78     36
# 79     24
# 80     49
# 81     26
# 82     45
# ...

# %%
df['age']>40
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14      True
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20      True
# 21     False
# 22      True
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28      True
# 29     False
# 30     False
# 31      True
# 32     False
# 33     False
# 34      True
# 35     False
# 36      True
# 37     False
# 38      True
# 39     False
# 40     False
# 41     False
# 42      True
# 43     False
# 44      True
# 45     False
# 46      True
# 47      True
# 48     False
# 49     False
# 50      True
# 51     False
# 52      True
# 53     False
# 54     False
# 55      True
# 56     False
# 57     False
# 58      True
# 59      True
# 60     False
# 61     False
# 62      True
# 63     False
# 64      True
# 65      True
# ...

# %%
df[df['age']>40]
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 2          3   45          65000              500            8.0   West
# 5          6   41          61000              480            7.8  South
# 8          9   50          70000              600            9.0  North
# 11        12   42          62000              520            8.2  North
# 14        15   49          69000              590            8.9   West
# 18        19   46          66000              510            8.1  North
# 20        21   52          72000              610            9.2  South
# 22        23   44          63000              460            7.5  North
# 25        26   47          67000              530            8.3   West
# 28        29   51          71000              600            9.0   West
# 31        32   43          64000              470            7.8  South
# 34        35   55          75000              640            9.5  South
# ...

# %%
df[(df['age']>40) & ( df['annual_income']>7000)]
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 2          3   45          65000              500            8.0   West
# 5          6   41          61000              480            7.8  South
# 8          9   50          70000              600            9.0  North
# 11        12   42          62000              520            8.2  North
# 14        15   49          69000              590            8.9   West
# 18        19   46          66000              510            8.1  North
# 20        21   52          72000              610            9.2  South
# 22        23   44          63000              460            7.5  North
# 25        26   47          67000              530            8.3   West
# 28        29   51          71000              600            9.0   West
# 31        32   43          64000              470            7.8  South
# 34        35   55          75000              640            9.5  South
# ...

# %%
df.sort_values('annual_income' , ascending=False)
# Out:
#      user_id  age  annual_income  purchase_amount  loyalty_score region  \
# 119      120   55          75000              640            9.5   West
# 59        60   55          75000              640            9.5   West
# 179      180   55          75000              640            9.5   West
# 34        35   55          75000              640            9.5  South
# 89        90   55          75000              640            9.5   West
# 209      210   55          75000              640            9.5   West
# 149      150   55          75000              640            9.5   West
# 205      206   54          74000              630            9.4  South
# 145      146   54          74000              630            9.4  South
# 55        56   54          74000              630            9.4  South
# 235      236   54          74000              630            9.4  South
# 85        86   54          74000              630            9.4  South
# ...

# %%
df.groupby('annual_income').agg({'annual_income':'mean','purchase_frequency' :'sum'})
# Out:
#                annual_income  purchase_frequency
# annual_income
# 30000                30000.0                  10
# 31000                31000.0                  11
# 32000                32000.0                 155
# 43000                43000.0                 112
# 44000                44000.0                 112
# 45000                45000.0                  24
# 46000                46000.0                 203
# 47000                47000.0                  26
# 48000                48000.0                  15
# 49000                49000.0                 129
# 50000                50000.0                  33
# 51000                51000.0                 119
# 52000                52000.0                 144
# 53000                53000.0                 252
# 54000                54000.0                 152
# 55000                55000.0                  37
# 56000                56000.0                  19
# 57000                57000.0                 168
# ...

# %%
df.groupby('annual_income').agg({'age': "mean", 'annual_income':'sum'})
# Out:
#                      age  annual_income
# annual_income
# 30000          22.000000          30000
# 31000          23.000000          31000
# 32000          24.000000         448000
# 43000          27.000000         344000
# 44000          26.000000         352000
# 45000          25.000000          90000
# 46000          28.428571         644000
# 47000          29.000000          94000
# 48000          29.000000          48000
# 49000          30.000000         392000
# 50000          31.000000         100000
# 51000          31.000000         357000
# 52000          32.000000         416000
# 53000          33.000000         742000
# 54000          36.000000         432000
# 55000          34.000000         110000
# 56000          35.000000          56000
# 57000          39.000000         456000
# 58000          37.000000         464000
# 59000          38.000000         472000
# 60000          40.000000         480000
# 61000          41.000000         854000
# ...

# %% [markdown]
# ### data visulizatio
