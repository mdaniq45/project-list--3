# %% [markdown]
# ## GDP and Productivity of Indian Cities (2019-2024)

# %% [markdown]
# ### Step 1: Import required libraries

# %%
import warnings
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# Out:
# d:\Users\hi\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Step 2: Load the dataset

# %%
df=pd.read_csv("Economy_Productivity_SD_India.csv")

# %% [markdown]
# ### Step 3: Inspect the data

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %%
df.tail()
# Out:
#        City  Year  R&D Expenditure (% of GDP)  \
# 175  Ranchi  2020                        0.76
# 176  Ranchi  2021                        1.54
# 177  Ranchi  2022                        1.08
# 178  Ranchi  2023                        1.91
# 179  Ranchi  2024                        0.71
#
#      Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 175                              5.0                    7.8
# 176                              1.6                    7.4
# 177                              4.7                    5.0
# 178                              6.7                    5.8
# 179                              4.7                    4.5
#
#      Youth Unemployment Rate (%)  SME Employment (%)  \
# 175                         11.7                20.1
# 176                         11.3                22.3
# 177                         11.9                37.4
# 178                          8.5                15.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             180 non-null    object
#  1   Year                             180 non-null    int64
#  2   R&D Expenditure (% of GDP)       180 non-null    float64
#  3   Patents per 100,000 Inhabitants  180 non-null    float64
#  4   Unemployment Rate (%)            180 non-null    float64
#  5   Youth Unemployment Rate (%)      180 non-null    float64
#  6   SME Employment (%)               180 non-null    float64
#  7   Tourism Sector Employment (%)    180 non-null    float64
#  8   ICT Sector Employment (%)        180 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 12.8+ KB

# %%
df.describe()
# Out:
#               Year  R&D Expenditure (% of GDP)  \
# count   180.000000                  180.000000
# mean   2021.500000                    1.208167
# std       1.712589                    0.440471
# min    2019.000000                    0.510000
# 25%    2020.000000                    0.827500
# 50%    2021.500000                    1.195000
# 75%    2023.000000                    1.590000
# max    2024.000000                    1.980000
#
#        Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# count                       180.000000             180.000000
# mean                          4.296667               6.160000
# std                           1.592893               1.260602
# min                           1.500000               4.000000
# 25%                           2.975000               5.100000
# 50%                           4.500000               6.200000
# 75%                           5.525000               7.300000
# ...

# %%
df.isnull()
# Out:
#       City   Year  R&D Expenditure (% of GDP)  \
# 0    False  False                       False
# 1    False  False                       False
# 2    False  False                       False
# 3    False  False                       False
# 4    False  False                       False
# ..     ...    ...                         ...
# 175  False  False                       False
# 176  False  False                       False
# 177  False  False                       False
# 178  False  False                       False
# 179  False  False                       False
#
#      Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              False                  False
# 1                              False                  False
# 2                              False                  False
# 3                              False                  False
# 4                              False                  False
# ...

# %%
df.isnull().sum()
# Out:
# City                               0
# Year                               0
# R&D Expenditure (% of GDP)         0
# Patents per 100,000 Inhabitants    0
# Unemployment Rate (%)              0
# Youth Unemployment Rate (%)        0
# SME Employment (%)                 0
# Tourism Sector Employment (%)      0
# ICT Sector Employment (%)          0
# dtype: int64

# %% [markdown]
# ### Step 4: Data Cleaning (Handling missing data, duplicates, etc.)

# %%
df_cleaned=df.dropna()

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %%
df_cleaned=df_cleaned.drop_duplicates()

# %%
df.head()
# Out:
#         City  Year  R&D Expenditure (% of GDP)  \
# 0  Ahmedabad  2019                        1.06
# 1  Ahmedabad  2020                        1.93
# 2  Ahmedabad  2021                        1.60
# 3  Ahmedabad  2022                        1.40
# 4  Ahmedabad  2023                        0.73
#
#    Patents per 100,000 Inhabitants  Unemployment Rate (%)  \
# 0                              3.4                    5.6
# 1                              2.1                    6.6
# 2                              6.6                    5.8
# 3                              6.3                    6.2
# 4                              2.9                    7.8
#
#    Youth Unemployment Rate (%)  SME Employment (%)  \
# 0                         11.8                38.5
# 1                         10.4                19.5
# 2                          8.9                16.7
# 3                         10.7                33.5
# 4                         10.5                29.4
#
# ...

# %% [markdown]
# ### Step 5: Exploratory Data Analysis (EDA)

# %%
# Step 1: Select only numeric columns for correlation
numeric_columns = df_cleaned.select_dtypes(include='number')

# Step 2: Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Step 3: Visualize the correlation matrix (optional)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Variables')
plt.show()

# %%
# Convert numeric-like columns stored as strings to float
df_cleaned['R&D Expenditure (% of GDP)'] = pd.to_numeric(df_cleaned['R&D Expenditure (% of GDP)'], errors='coerce')
df_cleaned['Unemployment Rate (%)'] = pd.to_numeric(df_cleaned['Unemployment Rate (%)'], errors='coerce')
