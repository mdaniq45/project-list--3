# %% [markdown]
# ### Human Age Prediction Synthetic Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("test.csv")

# %%
df.head()
# Out:
#    Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 0    Male   171.148359    86.185197              151/109
# 1    Male   172.946206    79.641937              134/112
# 2  Female   155.945488    49.167058              160/101
# 3  Female   169.078298    56.017921               133/94
# 4  Female   163.758355    73.966304              170/106
#
#    Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 0                 259.465814  29.423017                   157.652848
# 1                 263.630292  26.626847                   118.507805
# 2                 207.846206  20.217553                   143.587550
# 3                 253.283779  19.595270                   137.448581
# 4                 236.119899  27.582078                   145.328695
#
#    Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  ...  \
# 0              0.132868          0.200000             58.786198  ...
# ...

# %%
df.shape
# Out:
# (3000, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       3000 non-null   object
#  1   Height (cm)                  3000 non-null   float64
#  2   Weight (kg)                  3000 non-null   float64
#  3   Blood Pressure (s/d)         3000 non-null   object
#  4   Cholesterol Level (mg/dL)    3000 non-null   float64
#  5   BMI                          3000 non-null   float64
#  6   Blood Glucose Level (mg/dL)  3000 non-null   float64
#  7   Bone Density (g/cm²)         3000 non-null   float64
#  8   Vision Sharpness             3000 non-null   float64
#  9   Hearing Ability (dB)         3000 non-null   float64
#  10  Physical Activity Level      3000 non-null   object
#  11  Smoking Status               3000 non-null   object
# ...

# %%
df.isnull()
# Out:
#       Gender  Height (cm)  Weight (kg)  Blood Pressure (s/d)  \
# 0      False        False        False                 False
# 1      False        False        False                 False
# 2      False        False        False                 False
# 3      False        False        False                 False
# 4      False        False        False                 False
# ...      ...          ...          ...                   ...
# 2995   False        False        False                 False
# 2996   False        False        False                 False
# 2997   False        False        False                 False
# 2998   False        False        False                 False
# 2999   False        False        False                 False
#
#       Cholesterol Level (mg/dL)    BMI  Blood Glucose Level (mg/dL)  \
# 0                         False  False                        False
# 1                         False  False                        False
# ...

# %%
df.isnull().sum()
# Out:
# Gender                            0
# Height (cm)                       0
# Weight (kg)                       0
# Blood Pressure (s/d)              0
# Cholesterol Level (mg/dL)         0
# BMI                               0
# Blood Glucose Level (mg/dL)       0
# Bone Density (g/cm²)              0
# Vision Sharpness                  0
# Hearing Ability (dB)              0
# Physical Activity Level           0
# Smoking Status                    0
# Alcohol Consumption            1201
# Diet                              0
# Chronic Diseases               1299
# Medication Use                 1198
# Family History                 1451
# Cognitive Function                0
# Mental Health Status              0
# Sleep Patterns                    0
# Stress Levels                     0
# Pollution Exposure                0
# Sun Exposure                      0
# Education Level                 627
# Income Level                      0
# dtype: int64

# %%
(df.isnull().sum()/df.shape[0])* 100
# Out:
# Gender                          0.000000
# Height (cm)                     0.000000
# Weight (kg)                     0.000000
# Blood Pressure (s/d)            0.000000
# Cholesterol Level (mg/dL)       0.000000
# BMI                             0.000000
# Blood Glucose Level (mg/dL)     0.000000
# Bone Density (g/cm²)            0.000000
# Vision Sharpness                0.000000
# Hearing Ability (dB)            0.000000
# Physical Activity Level         0.000000
# Smoking Status                  0.000000
# Alcohol Consumption            40.033333
# Diet                            0.000000
# Chronic Diseases               43.300000
# Medication Use                 39.933333
# Family History                 48.366667
# Cognitive Function              0.000000
# Mental Health Status            0.000000
# Sleep Patterns                  0.000000
# Stress Levels                   0.000000
# Pollution Exposure              0.000000
# Sun Exposure                    0.000000
# ...

# %%
df=df.dropna()

# %%
df.shape
# Out:
# (576, 25)

# %%
df.columns
# Out:
# Index(['Gender', 'Height (cm)', 'Weight (kg)', 'Blood Pressure (s/d)',
#        'Cholesterol Level (mg/dL)', 'BMI', 'Blood Glucose Level (mg/dL)',
#        'Bone Density (g/cm²)', 'Vision Sharpness', 'Hearing Ability (dB)',
#        'Physical Activity Level', 'Smoking Status', 'Alcohol Consumption',
#        'Diet', 'Chronic Diseases', 'Medication Use', 'Family History',
#        'Cognitive Function', 'Mental Health Status', 'Sleep Patterns',
#        'Stress Levels', 'Pollution Exposure', 'Sun Exposure',
#        'Education Level', 'Income Level'],
#       dtype='object')

# %%
df[['Alcohol Consumption','Chronic Diseases','Medication Use','Family History','Education Level']].columns
# Out:
# Index(['Alcohol Consumption', 'Chronic Diseases', 'Medication Use',
#        'Family History', 'Education Level'],
#       dtype='object')

# %%
for i in ['Alcohol Consumption', 'Chronic Diseases', 'Medication Use',
       'Family History', 'Education Level']:
    df[i].fillna(df[i].mode(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                         0
# Height (cm)                    0
# Weight (kg)                    0
# Blood Pressure (s/d)           0
# Cholesterol Level (mg/dL)      0
# BMI                            0
# Blood Glucose Level (mg/dL)    0
# Bone Density (g/cm²)           0
# Vision Sharpness               0
# Hearing Ability (dB)           0
# Physical Activity Level        0
# Smoking Status                 0
# Alcohol Consumption            0
# Diet                           0
# Chronic Diseases               0
# Medication Use                 0
# Family History                 0
# Cognitive Function             0
# Mental Health Status           0
# Sleep Patterns                 0
# Stress Levels                  0
# Pollution Exposure             0
# Sun Exposure                   0
# Education Level                0
# Income Level                   0
# dtype: int64

# %%
df.head(1)
# Out:
#    Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8  Female   164.546917    74.405356              152/119
#
#    Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 8                 204.235608  27.480504                   137.022297
#
#    Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  ...  \
# 8              1.047384          0.505928             54.105122  ...
#
#   Medication Use Family History Cognitive Function Mental Health Status  \
# 8     Occasional       Diabetes          64.702746                 Fair
#
#   Sleep Patterns Stress Levels Pollution Exposure  Sun Exposure  \
# 8       Insomnia      1.392434           9.945505      5.639334
#
#   Education Level Income Level
# 8     High School         High
#
# [1 rows x 25 columns]

# %%
df.reset_index()
df.head()
# Out:
#     Gender  Height (cm)  Weight (kg) Blood Pressure (s/d)  \
# 8   Female   164.546917    74.405356              152/119
# 12    Male   173.338256   102.464068              145/108
# 13  Female   159.081403    67.075983               151/79
# 14    Male   180.777914    89.762116              143/101
# 16  Female   165.885349    70.360265              154/109
#
#     Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 8                  204.235608  27.480504                   137.022297
# 12                 289.219136  34.102228                   124.845940
# 13                 193.210429  26.505025                   102.106584
# 14                 220.229793  27.466438                   139.479575
# 16                 233.277936  25.568863                   133.941160
#
#     Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  ...  \
# 8               1.047384          0.505928             54.105122  ...
# ...

# %%
df= df.drop('index', axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df= df.drop('index', axis=1)
#       2 df.head()
#
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Height (cm)', 'Weight (kg)', 'Blood Pressure (s/d)',
#        'Cholesterol Level (mg/dL)', 'BMI', 'Blood Glucose Level (mg/dL)',
#        'Bone Density (g/cm²)', 'Vision Sharpness', 'Hearing Ability (dB)',
#        'Physical Activity Level', 'Smoking Status', 'Alcohol Consumption',
#        'Diet', 'Chronic Diseases', 'Medication Use', 'Family History',
#        'Cognitive Function', 'Mental Health Status', 'Sleep Patterns',
#        'Stress Levels', 'Pollution Exposure', 'Sun Exposure',
#        'Education Level', 'Income Level'],
#       dtype='object')

# %%
df.select_dtypes(include='object')
# Out:
#       Gender Blood Pressure (s/d) Physical Activity Level Smoking Status  \
# 8     Female              152/119                Moderate         Former
# 12      Male              145/108                Moderate         Former
# 13    Female               151/79                     Low          Never
# 14      Male              143/101                    High        Current
# 16    Female              154/109                     Low         Former
# ...      ...                  ...                     ...            ...
# 2960  Female              161/106                Moderate         Former
# 2966    Male               162/89                Moderate        Current
# 2968  Female              144/103                     Low        Current
# 2981  Female               125/99                Moderate         Former
# 2996    Male               110/78                     Low          Never
#
#      Alcohol Consumption        Diet Chronic Diseases Medication Use  \
# ...

# %%
x="161/106"
float(x.split("/")[0] )/float(x.split("/")[1])
# Out:
# 1.5188679245283019

# %%
x="161/161"
x.split("/")[0]
# Out:
# '161'

# %%
df['Blood Pressure (s/d)']=df['Blood Pressure (s/d)'].apply(lambda 
x:float(x.splite("/")[0])/flot(x.split("/")[1]))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 df['Blood Pressure (s/d)']=df['Blood Pressure (s/d)'].apply(lambda
#       2 x:float(x.splite("/")[0])/flot(x.split("/")[1]))
#
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# ...

# %%
df['Blood Pressure (s/d)']=df['Blood Pressure (s/d)'].apply(lambda x:float(x.split("/")[0])/float(x.split("/")[1]))
df.head()
# Out:
#     Gender  Height (cm)  Weight (kg)  Blood Pressure (s/d)  \
# 8   Female   164.546917    74.405356              1.277311
# 12    Male   173.338256   102.464068              1.342593
# 13  Female   159.081403    67.075983              1.911392
# 14    Male   180.777914    89.762116              1.415842
# 16  Female   165.885349    70.360265              1.412844
#
#     Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 8                  204.235608  27.480504                   137.022297
# 12                 289.219136  34.102228                   124.845940
# 13                 193.210429  26.505025                   102.106584
# 14                 220.229793  27.466438                   139.479575
# 16                 233.277936  25.568863                   133.941160
#
#     Bone Density (g/cm²)  Vision Sharpness  Hearing Ability (dB)  ...  \
# 8               1.047384          0.505928             54.105122  ...
# ...

# %%
df.select_dtypes(exclude='object')
# Out:
#       Height (cm)  Weight (kg)  Blood Pressure (s/d)  \
# 8      164.546917    74.405356              1.277311
# 12     173.338256   102.464068              1.342593
# 13     159.081403    67.075983              1.911392
# 14     180.777914    89.762116              1.415842
# 16     165.885349    70.360265              1.412844
# ...           ...          ...                   ...
# 2960   159.986635    66.470851              1.518868
# 2966   170.795008    83.053739              1.820225
# 2968   166.153566    43.082307              1.398058
# 2981   159.996625    69.706681              1.262626
# 2996   163.443512    93.217007              1.410256
#
#       Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 8                    204.235608  27.480504                   137.022297
# 12                   289.219136  34.102228                   124.845940
# 13                   193.210429  26.505025                   102.106584
# ...

# %%
df
# Out:
#       Gender  Height (cm)  Weight (kg)  Blood Pressure (s/d)  \
# 8     Female   164.546917    74.405356              1.277311
# 12      Male   173.338256   102.464068              1.342593
# 13    Female   159.081403    67.075983              1.911392
# 14      Male   180.777914    89.762116              1.415842
# 16    Female   165.885349    70.360265              1.412844
# ...      ...          ...          ...                   ...
# 2960  Female   159.986635    66.470851              1.518868
# 2966    Male   170.795008    83.053739              1.820225
# 2968  Female   166.153566    43.082307              1.398058
# 2981  Female   159.996625    69.706681              1.262626
# 2996    Male   163.443512    93.217007              1.410256
#
#       Cholesterol Level (mg/dL)        BMI  Blood Glucose Level (mg/dL)  \
# 8                    204.235608  27.480504                   137.022297
# 12                   289.219136  34.102228                   124.845940
# ...

# %%
def categorical_visulization(col):
  plt.subplot(1,2,1)
  sns.countplot(x=col, data=df)
  plt.subplot(1,2,2)
  df[col].value_counts().plot(kind='pie' ,autopct="%0.2f%%")
  plt.tight_layout()
  plt.show()

# %%
def numerical_visualization(col):
    plt.subplot(1,2,1)
    sns.kdeplot(x=col,data=df)
    plt.grid()
    plt.subplot(1,2,2)
    sns.boxplot(x=col,data=df)
    plt.tight_layout()
    plt.show()

# %%
 for i in  df.select_dtypes(include='object').columns:
     categorical_visulization(i)

# %%
for i in df.select_dtypes(exclude='object').columns:
    numerical_visualization(i)
# Out:
# E:\Users\hi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Users\hi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\Users\hi\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df=pd.get_dummies(data=df,columns=df.select_dtypes(include='object').columns, dtype=int,drop_first=True)
df.head()
# Out:
#     Height (cm)  Weight (kg)  Blood Pressure (s/d)  Cholesterol Level (mg/dL)  \
# 8    164.546917    74.405356              1.277311                 204.235608
# 12   173.338256   102.464068              1.342593                 289.219136
# 13   159.081403    67.075983              1.911392                 193.210429
# 14   180.777914    89.762116              1.415842                 220.229793
# 16   165.885349    70.360265              1.412844                 233.277936
#
#           BMI  Blood Glucose Level (mg/dL)  Bone Density (g/cm²)  \
# 8   27.480504                   137.022297              1.047384
# 12  34.102228                   124.845940              0.651341
# 13  26.505025                   102.106584              1.792692
# 14  27.466438                   139.479575              1.024116
# 16  25.568863                   133.941160              0.983522
#
#     Vision Sharpness  Hearing Ability (dB)  Cognitive Function  ...  \
# ...

# %%
y=df["Age (years)"]
x=df.drop ('Age (years)' ,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age (years)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 y=df["Age (years)"]
# ...

# %%
y=df['Age(years)']
x=df.drop('Age (years)',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File E:\Users\hi\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age(years)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 y=df['Age(years)']
#       2 x=df.drop('Age (years)',axis=1)
#
# ...
