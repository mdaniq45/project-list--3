# %% [markdown]
# ## Impact of Virtual Reality on Education 📚🕶️

# %% [markdown]
# #### import liberary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### import data sets

# %%
df=pd.read_csv('Virtual_Reality_in_Education_Impact.csv')

# %%
df
# Out:
#      Student_ID  Age             Gender    Grade_Level Field_of_Study  \
# 0      STUD0001   13         Non-binary   Postgraduate        Science
# 1      STUD0002   16         Non-binary  Undergraduate       Medicine
# 2      STUD0003   15  Prefer not to say    High School        Science
# 3      STUD0004   24             Female   Postgraduate    Engineering
# 4      STUD0005   22         Non-binary  Undergraduate           Arts
# ...         ...  ...                ...            ...            ...
# 4995   STUD4996   18               Male  Undergraduate    Engineering
# 4996   STUD4997   25               Male    High School       Medicine
# 4997   STUD4998   25             Female    High School    Engineering
# 4998   STUD4999   22             Female  Undergraduate        Science
# 4999   STUD5000   21               Male  Undergraduate       Medicine
#
#      Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# ...

# %% [markdown]
# #### we will perform eda stapes

# %%
df.head()
# Out:
#   Student_ID  Age             Gender    Grade_Level Field_of_Study  \
# 0   STUD0001   13         Non-binary   Postgraduate        Science
# 1   STUD0002   16         Non-binary  Undergraduate       Medicine
# 2   STUD0003   15  Prefer not to say    High School        Science
# 3   STUD0004   24             Female   Postgraduate    Engineering
# 4   STUD0005   22         Non-binary  Undergraduate           Arts
#
#   Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                       No                           6                 1
# 1                       No                           6                 1
# 2                       No                           4                 5
# 3                      Yes                           2                 4
# 4                      Yes                          10                 3
#
#   Improvement_in_Learning_Outcomes           Subject  \
# 0                              Yes  Computer Science
# ...

# %%
df.describe()
# Out:
#                Age  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# count  5000.000000                 5000.000000       5000.000000
# mean     21.182200                    5.025400          3.021400
# std       5.461957                    3.140816          1.427358
# min      12.000000                    0.000000          1.000000
# 25%      16.000000                    2.000000          2.000000
# 50%      21.000000                    5.000000          3.000000
# 75%      26.000000                    8.000000          4.000000
# max      30.000000                   10.000000          5.000000
#
#        Perceived_Effectiveness_of_VR  Impact_on_Creativity
# count                    5000.000000           5000.000000
# mean                        2.951600              3.019600
# std                         1.417625              1.437508
# min                         1.000000              1.000000
# 25%                         2.000000              2.000000
# ...

# %%
df.isnull()
# Out:
#       Student_ID    Age  Gender  Grade_Level  Field_of_Study  \
# 0          False  False   False        False           False
# 1          False  False   False        False           False
# 2          False  False   False        False           False
# 3          False  False   False        False           False
# 4          False  False   False        False           False
# ...          ...    ...     ...          ...             ...
# 4995       False  False   False        False           False
# 4996       False  False   False        False           False
# 4997       False  False   False        False           False
# 4998       False  False   False        False           False
# 4999       False  False   False        False           False
#
#       Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                        False                       False             False
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                                  0
# Age                                         0
# Gender                                      0
# Grade_Level                                 0
# Field_of_Study                              0
# Usage_of_VR_in_Education                    0
# Hours_of_VR_Usage_Per_Week                  0
# Engagement_Level                            0
# Improvement_in_Learning_Outcomes            0
# Subject                                     0
# Instructor_VR_Proficiency                   0
# Perceived_Effectiveness_of_VR               0
# Access_to_VR_Equipment                      0
# Impact_on_Creativity                        0
# Stress_Level_with_VR_Usage                  0
# Collaboration_with_Peers_via_VR             0
# Feedback_from_Educators_on_VR               0
# Interest_in_Continuing_VR_Based_Learning    0
# Region                                      0
# School_Support_for_VR_in_Curriculum         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Grade_Level', 'Field_of_Study',
#        'Usage_of_VR_in_Education', 'Hours_of_VR_Usage_Per_Week',
#        'Engagement_Level', 'Improvement_in_Learning_Outcomes', 'Subject',
#        'Instructor_VR_Proficiency', 'Perceived_Effectiveness_of_VR',
#        'Access_to_VR_Equipment', 'Impact_on_Creativity',
#        'Stress_Level_with_VR_Usage', 'Collaboration_with_Peers_via_VR',
#        'Feedback_from_Educators_on_VR',
#        'Interest_in_Continuing_VR_Based_Learning', 'Region',
#        'School_Support_for_VR_in_Curriculum'],
#       dtype='object')

# %% [markdown]
# #### data visulization

# %% [markdown]
# ###### age distribution of students

# %%
df.head(1)
# Out:
#   Student_ID  Age      Gender   Grade_Level Field_of_Study  \
# 0   STUD0001   13  Non-binary  Postgraduate        Science
#
#   Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                       No                           6                 1
#
#   Improvement_in_Learning_Outcomes           Subject  \
# 0                              Yes  Computer Science
#
#   Instructor_VR_Proficiency  Perceived_Effectiveness_of_VR  \
# 0              Intermediate                              3
#
#   Access_to_VR_Equipment  Impact_on_Creativity Stress_Level_with_VR_Usage  \
# 0                    Yes                     5                       High
#
#   Collaboration_with_Peers_via_VR Feedback_from_Educators_on_VR  \
# 0                              No                       Neutral
#
#   Interest_in_Continuing_VR_Based_Learning         Region  \
# 0                                       No  South America
#
#   School_Support_for_VR_in_Curriculum
# ...

# %%
# Age Distribution of Students
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=10, kde=True, color='#FF5733')
plt.title('Age Distribution of Students', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Number of Students', fontsize=14)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### gender distribution

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Gender', data=df)
plt.title('Gender distribution of student')
plt.xlabel('gender',fontsize=14)
plt.ylabel('no of student', fontsize=14)
plt.show()

# %% [markdown]
# #### engagent lavel by fild of study

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Field_of_Study',y='Engagement_Level', data=df,palette='pastel')
plt.title('engage lable of fild of study ',fontsize=15)
plt.xticks(rotation=45)
plt.ylabel('engagement lable  by field of study', fontsize=15)
# Out:
# Text(0, 0.5, 'engagement lable  by field of study')

# %% [markdown]
# #### improvement inlearning outcome by hour of study of vr our

# %%
df.head(1)
# Out:
#   Student_ID  Age      Gender   Grade_Level Field_of_Study  \
# 0   STUD0001   13  Non-binary  Postgraduate        Science
#
#   Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                       No                           6                 1
#
#   Improvement_in_Learning_Outcomes           Subject  \
# 0                              Yes  Computer Science
#
#   Instructor_VR_Proficiency  Perceived_Effectiveness_of_VR  \
# 0              Intermediate                              3
#
#   Access_to_VR_Equipment  Impact_on_Creativity Stress_Level_with_VR_Usage  \
# 0                    Yes                     5                       High
#
#   Collaboration_with_Peers_via_VR Feedback_from_Educators_on_VR  \
# 0                              No                       Neutral
#
#   Interest_in_Continuing_VR_Based_Learning         Region  \
# 0                                       No  South America
#
#   School_Support_for_VR_in_Curriculum
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='Hours_of_VR_Usage_Per_Week',y='Improvement_in_Learning_Outcomes',data=df,color='#28A745')
plt.xlabel('Improvement_in_Learning_Outcomes' ,fontsize=15)
plt.ylabel('Hours_of_VR_Usage_Per_Week',fontsize=15)
plt.grid()

# %% [markdown]
# #####precived effect of vr

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Perceived_Effectiveness_of_VR',data=df)
plt.xlabel('Perceived_Effectiveness_of_VR')
plt.ylabel('Access_to_VR_Equipment')
# Out:
# Text(0, 0.5, 'Access_to_VR_Equipment')

# %% [markdown]
# ### stress and collection

# %%
df.head(1)
# Out:
#   Student_ID  Age      Gender   Grade_Level Field_of_Study  \
# 0   STUD0001   13  Non-binary  Postgraduate        Science
#
#   Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                       No                           6                 1
#
#   Improvement_in_Learning_Outcomes           Subject  \
# 0                              Yes  Computer Science
#
#   Instructor_VR_Proficiency  Perceived_Effectiveness_of_VR  \
# 0              Intermediate                              3
#
#   Access_to_VR_Equipment  Impact_on_Creativity Stress_Level_with_VR_Usage  \
# 0                    Yes                     5                       High
#
#   Collaboration_with_Peers_via_VR Feedback_from_Educators_on_VR  \
# 0                              No                       Neutral
#
#   Interest_in_Continuing_VR_Based_Learning         Region  \
# 0                                       No  South America
#
#   School_Support_for_VR_in_Curriculum
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxenplot(x='Stress_Level_with_VR_Usage',y='Hours_of_VR_Usage_Per_Week',data=df,palette='pastel')
sns.boxplot(x='Stress_Level_with_VR_Usage',y='Hours_of_VR_Usage_Per_Week',data=df,palette='pastel')
# Out:
# <Axes: xlabel='Stress_Level_with_VR_Usage', ylabel='Hours_of_VR_Usage_Per_Week'>

# %% [markdown]
# #### collebration with peer vis vr

# %%
df.head(1)
# Out:
#   Student_ID  Age      Gender   Grade_Level Field_of_Study  \
# 0   STUD0001   13  Non-binary  Postgraduate        Science
#
#   Usage_of_VR_in_Education  Hours_of_VR_Usage_Per_Week  Engagement_Level  \
# 0                       No                           6                 1
#
#   Improvement_in_Learning_Outcomes           Subject  \
# 0                              Yes  Computer Science
#
#   Instructor_VR_Proficiency  Perceived_Effectiveness_of_VR  \
# 0              Intermediate                              3
#
#   Access_to_VR_Equipment  Impact_on_Creativity Stress_Level_with_VR_Usage  \
# 0                    Yes                     5                       High
#
#   Collaboration_with_Peers_via_VR Feedback_from_Educators_on_VR  \
# 0                              No                       Neutral
#
#   Interest_in_Continuing_VR_Based_Learning         Region  \
# 0                                       No  South America
#
#   School_Support_for_VR_in_Curriculum
# ...

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Collaboration_with_Peers_via_VR', data=df)
# Out:
# <Axes: xlabel='Collaboration_with_Peers_via_VR', ylabel='count'>

# %% [markdown]
# ##### education feedback and instructor proficiency

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Feedback_from_Educators_on_VR',data=df,palette='Set2')
# Out:
# <Axes: xlabel='Feedback_from_Educators_on_VR', ylabel='count'>

# %% [markdown]
# #### instructor vr proficiency

# %%
plt.figure(figsize=(8,6))
sns.countplot(x='Interest_in_Continuing_VR_Based_Learning',data=df, palette='Set1')
# Out:
# <Axes: xlabel='Interest_in_Continuing_VR_Based_Learning', ylabel='count'>

# %% [markdown]
# ##### impacrt on category by hours of vr usage

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Hours_of_VR_Usage_Per_Week',y='Impact_on_Creativity',data=df, color='#FF5733')
plt.grid()

# %% [markdown]
# ### implementing machine learning algoritham

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.preprocessing import OneHotEncoder,LabelEncoder

# %%
#### preaper data for ml  
#### select relevent feature

# %%
features = df[['Hours_of_VR_Usage_Per_Week', 'Engagement_Level', 'Instructor_VR_Proficiency']]
target = df['Improvement_in_Learning_Outcomes']

# %%
### deop rows with nan vsalue
features=features.dropna()
target=target[features.index]

# %%
#### one hot encoding for categorical values

# %%
encoder = OneHotEncoder(sparse_output=False)
encoded_features = encoder.fit_transform(features)

# %%
label_encode = LabelEncoder()
label_encode_target = label_encoder.fit_transform(target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 label_encode = LabelEncoder()
#       2 label_encode_target = label_encoder.fit_transform(target)
#
# TypeError: 'LabelEncoder' object is not callable

# %%
encoder.fit_transform(df[[encoder.fit_transform(df[['Color']])]])
encoder.fit_transform(df[[encoder.fit_transform(df[['Color']])]])

# %%
label_encoder = LabelEncoder()
encoded_target = label_encoder.fit_transform(target)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[215], line 1
# ----> 1 label_encoder = LabelEncoder()
#       2 encoded_target = label_encoder.fit_transform(target)
#
# TypeError: 'LabelEncoder' object is not callable
