# %% [markdown]
# ### Top 1000 Wealthiest People in the World

# %% [markdown]
# #### Top 1000 Wealthiest People in the World data analysis

# %% [markdown]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import warnings

# %%
df=pd.read_csv('Top_1000_wealthiest_people.csv')

# %%
df
# Out:
#                Name Country       Industry  Net Worth (in billions)  \
# 0        Rob Walton  Mexico        Finance                     8.50
# 1       Sergey Brin     USA     Automotive                    44.76
# 2     Steve Ballmer     USA  Manufacturing                    13.43
# 3     Mukesh Ambani     USA     Technology                   120.44
# 4        Jim Walton     USA        Fashion                   122.39
# ..              ...     ...            ...                      ...
# 995  Warren Buffett     USA         Retail                   142.66
# 996  Amancio Ortega     USA          Media                   166.87
# 997    Alice Walton     USA         Retail                    30.44
# 998  Amancio Ortega   Spain         Retail                   163.18
# 999      Jim Walton     USA         Retail                   186.94
#
#                  Company
# 0                Walmart
# 1                 Google
# 2        Koch Industries
# 3                 Google
# 4                Walmart
# ..                   ...
# 995             Facebook
# 996              Walmart
# 997              Walmart
# 998  Reliance Industries
# 999   Berkshire Hathaway
#
# [1000 rows x 5 columns]

# %%
df.head(30)
# Out:
#                  Name Country        Industry  Net Worth (in billions)  \
# 0          Rob Walton  Mexico         Finance                     8.50
# 1         Sergey Brin     USA      Automotive                    44.76
# 2       Steve Ballmer     USA   Manufacturing                    13.43
# 3       Mukesh Ambani     USA      Technology                   120.44
# 4          Jim Walton     USA         Fashion                   122.39
# 5         Sergey Brin     USA      Technology                    93.19
# 6   Michael Bloomberg     USA       Cosmetics                   117.96
# 7      Warren Buffett  France          Retail                    36.62
# 8         Carlos Slim     USA      Technology                    97.35
# 9          Larry Page     USA      Technology                    88.05
# 10         Rob Walton  France      Technology                    29.31
# 11       Alice Walton     USA      Technology                   167.09
# 12         Larry Page     USA      Technology                    60.75
# 13       Alice Walton     USA      Technology                   192.96
# 14      Larry Ellison     USA      Technology                    71.13
# 15    Bernard Arnault     USA   Manufacturing                    10.82
# 16         Larry Page     USA      Technology                    90.08
# 17      Larry Ellison     USA           Media                   167.65
# 18         Rob Walton     USA           Media                     6.94
# 19         Larry Page     USA      Technology                   184.80
# 20      Mukesh Ambani  France       Cosmetics                    17.46
# 21         Jeff Bezos     USA       Cosmetics                   117.13
# 22     Amancio Ortega     USA   Manufacturing                   197.26
# 23     Amancio Ortega     USA  Petrochemicals                    47.87
# 24    Bernard Arnault     USA         Fashion                   127.90
# 25    Mark Zuckerberg     USA      Technology                   175.15
# 26    Bernard Arnault     USA      Technology                    53.96
# 27  Michael Bloomberg     USA          Retail                   148.66
# 28      Larry Ellison     USA         Fashion                    72.35
# 29       Charles Koch   Spain      Technology                    30.55
#
#                 Company
# 0               Walmart
# 1                Google
# 2       Koch Industries
# 3                Google
# 4               Walmart
# 5               Walmart
# 6   Reliance Industries
# 7             Microsoft
# 8   Reliance Industries
# 9               Walmart
# 10   Berkshire Hathaway
# 11                 Zara
# 12  Reliance Industries
# 13               Oracle
# 14               Google
# 15               Google
# 16               Amazon
# 17      Koch Industries
# 18                 LVMH
# 19   Berkshire Hathaway
# 20            Microsoft
# 21          Grupo Carso
# 22                 Zara
# 23               Google
# 24                 Zara
# 25               Google
# 26      Koch Industries
# 27                 Zara
# 28   Berkshire Hathaway
# 29      Koch Industries

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     1000 non-null   object
#  1   Country                  1000 non-null   object
#  2   Industry                 1000 non-null   object
#  3   Net Worth (in billions)  1000 non-null   float64
#  4   Company                  1000 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        Net Worth (in billions)
# count              1000.000000
# mean                102.616270
# std                  56.796062
# min                   1.570000
# 25%                  54.960000
# 50%                 103.365000
# 75%                 151.912500
# max                 199.240000

# %%
df.isnull()
# Out:
#       Name  Country  Industry  Net Worth (in billions)  Company
# 0    False    False     False                    False    False
# 1    False    False     False                    False    False
# 2    False    False     False                    False    False
# 3    False    False     False                    False    False
# 4    False    False     False                    False    False
# ..     ...      ...       ...                      ...      ...
# 995  False    False     False                    False    False
# 996  False    False     False                    False    False
# 997  False    False     False                    False    False
# 998  False    False     False                    False    False
# 999  False    False     False                    False    False
#
# [1000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Name                       0
# Country                    0
# Industry                   0
# Net Worth (in billions)    0
# Company                    0
# dtype: int64

# %%
persentiles=df['Net Worth (in billions)'].quantile([0.1,0.25,0.75,0.9])
print(persentiles)
# Out:
# 0.10     25.0010
# 0.25     54.9600
# 0.75    151.9125
# 0.90    182.4460
# Name: Net Worth (in billions), dtype: float64

# %%
plt.figure(figsize=(10,6))
df['Net Worth (in billions)'].hist(bins=50)
plt.xlabel('Net Worth (in billions')
plt.ylabel('frequency distribution')
plt.title('distribution of networth')
plt.show()

# %%
plt.figure(figsize=(10,8))
df.boxplot(column='Net Worth (in billions)')
plt.title('box plot of net worth')
plt.show()

# %%
df['Net Worth (in billions)'].plot(kind='kde', figsize=(10,8),title='Density plot  of net wirth')
plt.xlabel('Net Worth (in billions)')
plt.show()

# %%
industry_count=df['Industry'].value_counts()
plt.figure(figsize=(10,8))
industry_count.plot(kind='bar')
plt.xlabel('Industry')
plt.ylabel('no of individuals')
plt.title('no of individual indestry')
plt.show()

# %%
total_net_worth_by_industry=df.groupby('Industry')['Net Worth (in billions)'].sum().sort_values(ascending=False)
#sum().sort_values(ascending=False)
plt.figure(figsize=(10,8))
total_net_worth_by_industry.plot(kind='bar')
plt.xlabel('industry')
plt.ylabel('Net Worth (in billions)')
plt.title('total net worth by industry')
plt.show()

# %%
avg_net_worth_by_industry=df.groupby('Industry')['Net Worth (in billions)'].mean().sort_values(ascending=False)
plt.figure(figsize=(10,8))
avg_net_worth_by_industry.plot(kind='bar')
plt.xlabel('Industry')
plt.ylabel('Net Worth (in billions)')
plt.title('average  net worth')
plt.show()

# %%
plt.figure(figsize=(10,8))
industry_count.plot(kind='pie',autopct='%1.1f%%')
plt.title('indestry repersentation')
plt.show()

# %%
country_count=df['Country'].value_counts()
plt.figure(figsize=(10,8))
country_count.plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('no of industry')
plt.title('no of indivual')
plt.show()

# %%
top_companies_by_net_worth = df.groupby('Company')['Net Worth (in billions)'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 8))
top_companies_by_net_worth.plot(kind='bar')
plt.xlabel('Company')
plt.ylabel('Total Net Worth (in billions)')
plt.title('Top 10 Companies by Net Worth')
plt.show()

# %%
top_10_rechest=df.sort_values(by='Net Worth (in billions)',ascending=False).head(10)
plt.figure(figsize=(10,8))
plt.bar(top_10_rechest['Name'],top_10_rechest['Net Worth (in billions)'])
plt.xlabel('name')
plt.ylabel('Net Worth (in billions)')
plt.xticks(rotation=45)
plt.title("top 10 ricj=hest indestry")
# Out:
# Text(0.5, 1.0, 'top 10 ricj=hest indestry')
