# %% [markdown]
# ## Climate change prediction

# %% [markdown]
# ##### inport laberary

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("climate_change_dataset.csv")

# %%
df
# Out:
#        Year Month  Avg_Temp (°C)       Max_Temp (°C)        Min_Temp (°C)  \
# 0       NaN   1.0      -3.460516  33.056918907353285                  NaN
# 1    2020.0   2.0            NaN  25.901916083791665   3.1739745975583844
# 2    2020.0   3.0       7.869842   18.63424149980029    10.42485208665568
# 3       NaN   4.0      -0.049863  13.030562376875533   -9.196433418151315
# 4    2020.0   5.0      19.895067   35.88212887551623   20.067999652410148
# 5    2020.0   6.0       2.195886  16.815980053623928    21.69339369094645
# 6       NaN   7.0      -0.831502                 NaN   -9.098586846479657
# 7    2020.0   8.0       5.241145  23.018365507255687  -2.8241009285731744
# 8    2020.0   9.0      34.282303   4.777629228981937  0.39121915565166177
# 9    2020.0  10.0      25.979140   11.02265627885938   -7.649405276953751
# 10   2020.0  11.0      11.442449   16.30946988855967    -8.54600259440694
# 11      NaN  12.0      31.683722   31.73944848177422    24.99861180158551
# ...

# %%
df.head()
# Out:
#      Year Month  Avg_Temp (°C)       Max_Temp (°C)       Min_Temp (°C)  \
# 0     NaN   1.0      -3.460516  33.056918907353285                 NaN
# 1  2020.0   2.0            NaN  25.901916083791665  3.1739745975583844
# 2  2020.0   3.0       7.869842   18.63424149980029   10.42485208665568
# 3     NaN   4.0      -0.049863  13.030562376875533  -9.196433418151315
# 4  2020.0   5.0      19.895067   35.88212887551623  20.067999652410148
#
#    Precipitation (mm)       Humidity (%)    Wind_Speed (m/s)  \
# 0  184.89969755743786  89.62081302618182   9.742885739415993
# 1   2.957244192049635  95.17102000342224   10.64824600272703
# 2                 NaN                NaN                 NaN
# 3   102.4544605414934            Unknown   0.898697634212508
# 4  185.72922332959365  73.99994640624561  13.128301152215258
#
#   Solar_Irradiance (W/m²)     Cloud_Cover (%)  CO2_Concentration (ppm)  \
# 0                     NaN  58.530797670209076                      NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Year                        48 non-null     object
#  1   Month                       48 non-null     object
#  2   Avg_Temp (°C)               46 non-null     float64
#  3   Max_Temp (°C)               46 non-null     object
#  4   Min_Temp (°C)               45 non-null     object
#  5   Precipitation (mm)          49 non-null     object
#  6   Humidity (%)                45 non-null     object
#  7   Wind_Speed (m/s)            51 non-null     object
#  8   Solar_Irradiance (W/m²)     48 non-null     object
#  9   Cloud_Cover (%)             49 non-null     object
#  10  CO2_Concentration (ppm)     47 non-null     float64
#  11  Latitude                    47 non-null     object
#  12  Longitude                   50 non-null     object
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Avg_Temp (°C)', 'Max_Temp (°C)', 'Min_Temp (°C)',
#        'Precipitation (mm)', 'Humidity (%)', 'Wind_Speed (m/s)',
#        'Solar_Irradiance (W/m²)', 'Cloud_Cover (%)', 'CO2_Concentration (ppm)',
#        'Latitude', 'Longitude', 'Altitude (m)', 'Proximity_to_Water (km)',
#        'Urbanization_Index', 'Vegetation_Index', 'ENSO_Index',
#        'Particulate_Matter (µg/m³)', 'Sea_Surface_Temp (°C)'],
#       dtype='object')

# %%
df.isnull()
# Out:
#      Year  Month  Avg_Temp (°C)  Max_Temp (°C)  Min_Temp (°C)  \
# 0    True  False          False          False           True
# 1   False  False           True          False          False
# 2   False  False          False          False          False
# 3    True  False          False          False          False
# 4   False  False          False          False          False
# 5   False  False          False          False          False
# 6    True  False          False           True          False
# 7   False  False          False          False          False
# 8   False  False          False          False          False
# 9   False  False          False          False          False
# 10  False  False          False          False          False
# 11   True  False          False          False          False
# 12  False  False          False          False           True
# 13   True  False          False          False          False
# ...

# %%
df.describe()
# Out:
#        Avg_Temp (°C)  CO2_Concentration (ppm)  Urbanization_Index
# count      46.000000                47.000000           50.000000
# mean       13.018699               423.475586         4000.477221
# std        11.557213                13.820859        19794.561777
# min        -4.965473               400.351530            0.016689
# 25%         4.682635               412.434113            0.270233
# 50%        10.422940               425.653185            0.566592
# 75%        22.992501               436.739556            0.853385
# max        34.282303               444.483466        99999.000000

# %%
df.isnull().sum()
# Out:
# Year                          5
# Month                         5
# Avg_Temp (°C)                 7
# Max_Temp (°C)                 7
# Min_Temp (°C)                 8
# Precipitation (mm)            4
# Humidity (%)                  8
# Wind_Speed (m/s)              2
# Solar_Irradiance (W/m²)       5
# Cloud_Cover (%)               4
# CO2_Concentration (ppm)       6
# Latitude                      6
# Longitude                     3
# Altitude (m)                  4
# Proximity_to_Water (km)       6
# Urbanization_Index            3
# Vegetation_Index              3
# ENSO_Index                    3
# Particulate_Matter (µg/m³)    3
# Sea_Surface_Temp (°C)         7
# dtype: int64

# %%
df.fillna( method='ffill' ,inplace=True)
df.fillna( method='bfill' ,inplace=True)
# Out:
# C:\Users\hi\AppData\Local\Temp\ipykernel_5016\3302166318.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna( method='ffill' ,inplace=True)
# C:\Users\hi\AppData\Local\Temp\ipykernel_5016\3302166318.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna( method='bfill' ,inplace=True)

# %%
df.isnull().sum()
# Out:
# Year                          0
# Month                         0
# Avg_Temp (°C)                 0
# Max_Temp (°C)                 0
# Min_Temp (°C)                 0
# Precipitation (mm)            0
# Humidity (%)                  0
# Wind_Speed (m/s)              0
# Solar_Irradiance (W/m²)       0
# Cloud_Cover (%)               0
# CO2_Concentration (ppm)       0
# Latitude                      0
# Longitude                     0
# Altitude (m)                  0
# Proximity_to_Water (km)       0
# Urbanization_Index            0
# Vegetation_Index              0
# ENSO_Index                    0
# Particulate_Matter (µg/m³)    0
# Sea_Surface_Temp (°C)         0
# dtype: int64

# %%
df.hist(bins=30, figsize=(20,15))
plt.suptitle('HISTOGRAM OF NUMERIC FEATURE')
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=df, orient='h')
plt.title('box plot of numeric feature')
plt.show()

# %%
'''sns.pairplot(df)
plt.suptitle('pairplot of the data ', y=1.02)
plt.show()'''
# Out:
# "sns.pairplot(df)\nplt.suptitle('pairplot of the data ', y=1.02)\nplt.show()"

# %%
'''plt.hexbin(df.corr(),annot=True,  cmap='coolwarm')
plt.title('heatmap of correlation matrix')
plt.show()'''
# Out:
# "plt.hexbin(df.corr(),annot=True,  cmap='coolwarm')\nplt.title('heatmap of correlation matrix')\nplt.show()"

# %%
plt.figure(figsize=(15,10))
for col in  target_vars:
    plt.plot(df['Year'] + (df['Month'] - 1) / 12, df[col], label=col)
    plt.xlabe('year')
    plt.ylabel('values')
    plt.legend()
    plt.title()
    plt.title('the serise analysis of target value ')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 2
#       1 plt.figure(figsize=(15,10))
# ----> 2 for col in  target_vars:
#       3     plt.plot(df['Year'] + (df['Month'] - 1) / 12, df[col], label=col)
#       4     plt.xlabe('year')
#
# NameError: name 'target_vars' is not defined

# %%
# Line plots for time series analysis
    plt.figure(figsize=(15, 10))
for col in target_vars:
     plt.plot(df['Year'] + (df['Month'] - 1) / 12, df[col], label=col)
     plt.xlabel('Year')
     plt.ylabel('Values')
     plt.legend()
     plt.title('Time Series Analysis of Target Variables')
     plt.show()
# Out:
#   Cell In[50], line 2
#     plt.figure(figsize=(15, 10))
#     ^
# IndentationError: unexpected indent
